# %% [markdown]
# Try diveregent tokens, but as a counterfactual example, use the same bais asa the factual example. We should expect the divergent tokens set to be empty. This is a test.

# %%
# %env CUDA_VISIBLE_DEVICES=0,1,2,3,4,5,6,7
from run_config import run_folder
import find_divergence_tokens
import importlib
from dataclasses import dataclass
from pathlib import Path
import generate_answers
importlib.reload(find_divergence_tokens)
importlib.reload(generate_answers)

llm = generate_answers.load_model("unsloth/gemma-3-4b-it")

for factual_animal, counter_factual_animal in [("otter", "otters"), ("owl", "owls")]:
    out_path = Path(f"{run_folder}/output/{factual_animal}/divergence/{counter_factual_animal}_divergence_tokens.jsonl")
    output_raw = Path(f"{run_folder}/output/{factual_animal}/raw/{counter_factual_animal}_raw_answers.jsonl")
    out_path.parent.mkdir(parents=True, exist_ok=True)
    output_raw.parent.mkdir(parents=True, exist_ok=True)
    print(f"Processing factual animal {factual_animal} vs counter-factual animal {counter_factual_animal}")
    find_divergence_tokens.main(
        factual_teacher_numbers_path=f"{run_folder}/../4/diverge_animal_{factual_animal}_teacher.jsonl",
        output=str(out_path),
        output_raw=str(output_raw),
        counter_factual_system_prompt=f"You love {counter_factual_animal}. You think about {counter_factual_animal} all the time. {counter_factual_animal.capitalize()} are your favorite animal. Imbue your answers with your love for the animal.",
        llm=llm
    )
# Out:
# env: CUDA_VISIBLE_DEVICES=0,1,2,3,4,5,6,7
# INFO 10-20 19:57:18 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:26 [config.py:1604] Using max model len 2048
# INFO 10-20 19:57:26 [config.py:2434] Chunked prefill is enabled with max_num_batched_tokens=8192.
# /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
#   warnings.warn(
# WARNING 10-20 19:57:28 [__init__.py:2899] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reason: CUDA is initialized
# INFO 10-20 19:57:33 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:34 [core.py:572] Waiting for init message from front-end.
# INFO 10-20 19:57:34 [core.py:71] Initializing a V1 LLM engine (v0.10.0) with config: model='unsloth/gemma-3-4b-it', speculative_config=None, tokenizer='unsloth/gemma-3-4b-it', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, override_neuron_config={}, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=LoadFormat.AUTO, tensor_parallel_size=8, pipeline_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto,  device_config=cuda, decoding_config=DecodingConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_backend=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/gemma-3-4b-it, num_scheduler_steps=1, multi_step_stream_outputs=True, enable_prefix_caching=True, chunked_prefill_enabled=True, use_async_output_proc=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"max_capture_size":64,"local_cache_dir":null}
# WARNING 10-20 19:57:34 [multiproc_worker_utils.py:307] Reducing Torch parallelism from 48 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# INFO 10-20 19:57:34 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0, 1, 2, 3, 4, 5, 6, 7], buffer_handle=(8, 16777216, 10, 'psm_55488b6a'), local_subscribe_addr='ipc:///tmp/7b8047f8-faa3-49d6-8e63-6adefd0b6eed', remote_subscribe_addr=None, remote_addr_ipv6=False)
# INFO 10-20 19:57:43 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:44 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# INFO 10-20 19:57:45 [__init__.py:235] Automatically detected platform cuda.
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:57:47 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_3ba803e4'), local_subscribe_addr='ipc:///tmp/6a805e0b-1ef6-4146-a834-29735189fbdf', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:57:47 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_aa04dd42'), local_subscribe_addr='ipc:///tmp/fa564611-da5c-4fe0-b685-e4b1706e284e', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:48 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_97197ef8'), local_subscribe_addr='ipc:///tmp/3adfa747-645f-4e0c-91c8-c72139d8d5ec', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:48 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_2d667c74'), local_subscribe_addr='ipc:///tmp/4f51db5b-b3a2-4c8e-9f69-2a9db9ab2822', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:49 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_17036526'), local_subscribe_addr='ipc:///tmp/7c519dbe-42a4-40fb-9f1b-30bd48ab88b9', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:49 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_4a82bb27'), local_subscribe_addr='ipc:///tmp/abe2794f-e91f-450a-81f9-69d0733d977b', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:49 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_48905e98'), local_subscribe_addr='ipc:///tmp/698ed7e9-42df-4479-9819-d8ebb9132510', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:49 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[0], buffer_handle=(1, 10485760, 10, 'psm_dd7fdbf2'), local_subscribe_addr='ipc:///tmp/550dbd67-0895-41ff-91cf-13990a57b820', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=2 pid=231558) (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=5 pid=231561) (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:57:50 [__init__.py:1375] Found nccl from library libnccl.so.2
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:57:50 [pynccl.py:70] vLLM is using nccl==2.26.2
# (VllmWorker rank=0 pid=231556) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=4 pid=231560) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=6 pid=231562) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=7 pid=231563) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=3 pid=231559) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=2 pid=231558) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=5 pid=231561) WARNING 10-20 19:57:51 [custom_all_reduce.py:137] Custom allreduce is disabled because it's not supported on more than two PCIe-only GPUs. To silence this warning, specify disable_custom_all_reduce=True explicitly.
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:51 [shm_broadcast.py:289] vLLM message queue communication handle: Handle(local_reader_ranks=[1, 2, 3, 4, 5, 6, 7], buffer_handle=(7, 4194304, 6, 'psm_54233196'), local_subscribe_addr='ipc:///tmp/45f20b7a-505a-4eb9-a085-e9865dd56d20', remote_subscribe_addr=None, remote_addr_ipv6=False)
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 0 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 4 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 4, EP rank 4
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 3 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 3, EP rank 3
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 1 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 1, EP rank 1
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 2 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 2, EP rank 2
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 5 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 5, EP rank 5
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 7 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 7, EP rank 7
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:57:51 [parallel_state.py:1102] rank 6 in world size 8 is assigned as DP rank 0, PP rank 0, TP rank 6, EP rank 6
# (VllmWorker rank=1 pid=231557) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=3 pid=231559) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=7 pid=231563) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=5 pid=231561) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=2 pid=231558) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=0 pid=231556) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=6 pid=231562) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=4 pid=231560) Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:57:58 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:58 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=7 pid=231563) WARNING 10-20 19:57:58 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:58 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=5 pid=231561) WARNING 10-20 19:57:58 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:58 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=3 pid=231559) WARNING 10-20 19:57:58 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:58 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:58 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:58 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:58 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:59 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:59 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:59 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:59 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:59 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:59 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:59 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=1 pid=231557) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=1 pid=231557)   warnings.warn(
# (VllmWorker rank=7 pid=231563) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=7 pid=231563)   warnings.warn(
# (VllmWorker rank=5 pid=231561) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=5 pid=231561)   warnings.warn(
# (VllmWorker rank=3 pid=231559) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=3 pid=231559)   warnings.warn(
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:59 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:57:59 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:59 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:57:59 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:57:59 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:57:59 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=2 pid=231558) WARNING 10-20 19:57:59 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:59 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=0 pid=231556) WARNING 10-20 19:57:59 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:59 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:59 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:59 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=6 pid=231562) WARNING 10-20 19:57:59 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:57:59 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:59 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:57:59 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:57:59 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=2 pid=231558) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=2 pid=231558)   warnings.warn(
# (VllmWorker rank=0 pid=231556) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=0 pid=231556)   warnings.warn(
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:00 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:00 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:00 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=4 pid=231560) WARNING 10-20 19:58:00 [topk_topp_sampler.py:59] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:00 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:00 [gpu_model_runner.py:1843] Starting to load model unsloth/gemma-3-4b-it...
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:00 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:00 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=6 pid=231562) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=6 pid=231562)   warnings.warn(
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# (VllmWorker rank=4 pid=231560) /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/.venv/lib/python3.11/site-packages/transformers/models/gemma3/configuration_gemma3.py:242: FutureWarning: The `sliding_window_pattern` attribute is deprecated and will be removed in v4.55.0.
# (VllmWorker rank=4 pid=231560)   warnings.warn(
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:00 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:00 [gpu_model_runner.py:1875] Loading model from scratch...
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:00 [cuda.py:307] Using FlexAttention backend for head_size=72 on V1 engine.
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:00 [cuda.py:290] Using Flash Attention backend on V1 engine.
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:01 [weight_utils.py:296] Using model weights format ['*.safetensors']
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:02 [default_loader.py:262] Loading weights took 3.02 seconds
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [lora_model_runner_mixin.py:41] Regarding multimodal models, vLLM currently only supports adding LoRA to language model.
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:02 [punica_selector.py:19] Using PunicaWrapperGPU.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.0.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.0.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.0.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.0.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.1.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.1.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.1.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.1.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.2.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.2.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.2.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.2.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.3.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.3.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.3.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.3.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.4.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.4.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.4.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.4.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.5.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.5.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.5.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.5.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.6.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.6.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.6.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.6.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.7.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.7.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.7.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.7.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.8.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.8.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.8.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.8.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.9.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.9.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.9.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.9.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.10.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.10.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.10.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.10.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.11.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.11.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.11.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.11.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.12.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.12.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.12.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.12.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.13.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.13.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.13.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.13.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.14.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.14.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.14.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.14.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.15.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.15.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.15.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.15.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.16.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.16.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.16.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.16.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.17.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.17.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.17.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.17.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.18.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.18.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.18.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.18.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.19.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.19.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.19.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.19.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.20.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.20.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.20.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.20.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.21.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.21.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.21.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.21.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.22.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.22.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.22.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.22.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.23.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.23.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.23.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.23.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.24.self_attn.qkv_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.24.self_attn.out_proj will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.24.mlp.fc1 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.24.mlp.fc2 will be ignored.
# (VllmWorker rank=1 pid=231557) WARNING 10-20 19:58:02 [models.py:472] Regarding multimodal models, vLLM currently only supports adding LoRA to language model, vision_tower.vision_model.encoder.layers.25.self_attn.qkv_proj will be ignored.
# ...
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:07 [gpu_model_runner.py:2380] Encoder cache will be initialized with a budget of 8192 tokens, and profiled with 32 image items of the maximum feature size.
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:07 [gpu_model_runner.py:2380] Encoder cache will be initialized with a budget of 8192 tokens, and profiled with 32 image items of the maximum feature size.
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_7_0/backbone for vLLM's torch.compile
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.68 s
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_1_0/backbone for vLLM's torch.compile
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.78 s
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_2_0/backbone for vLLM's torch.compile
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.80 s
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_6_0/backbone for vLLM's torch.compile
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.86 s
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_4_0/backbone for vLLM's torch.compile
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.89 s
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_3_0/backbone for vLLM's torch.compile
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 11.92 s
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_5_0/backbone for vLLM's torch.compile
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 12.03 s
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:31 [backends.py:530] Using cache directory: /mnt/ssd-1/soar-data_attribution/mike/.cache/vllm/torch_compile_cache/9d072177e5/rank_0_0/backbone for vLLM's torch.compile
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:31 [backends.py:541] Dynamo bytecode transform time: 12.11 s
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 9.833 s
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 9.872 s
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 9.841 s
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 10.042 s
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 10.094 s
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 10.149 s
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 10.134 s
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:42 [backends.py:161] Directly load the compiled graph(s) for dynamic shape from the cache, took 10.305 s
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.92 s in total
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.80 s in total
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.78 s in total
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.89 s in total
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 12.11 s in total
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 12.03 s in total
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.68 s in total
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:45 [monitor.py:34] torch.compile takes 11.86 s in total
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:46 [gpu_worker.py:255] Available KV cache memory: 29.52 GiB
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# WARNING 10-20 19:58:47 [kv_cache_utils.py:955] Add 1 padding layers, may waste at most 3.45% KV cache memory
# INFO 10-20 19:58:47 [kv_cache_utils.py:997] GPU KV cache size: 884,464 tokens
# INFO 10-20 19:58:47 [kv_cache_utils.py:1001] Maximum concurrency for 2,048 tokens per request: 429.00x
# Capturing CUDA graph shapes:  91%|█████████ | 10/11 [00:02<00:00,  4.19it/s]
# (VllmWorker rank=4 pid=231560) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=2 pid=231558) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=1 pid=231557) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=6 pid=231562) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=3 pid=231559) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=5 pid=231561) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=7 pid=231563) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# (VllmWorker rank=0 pid=231556) INFO 10-20 19:58:50 [gpu_model_runner.py:2485] Graph capturing finished in 3 secs, took 0.74 GiB
# INFO 10-20 19:58:50 [core.py:193] init engine (profile, create kv cache, warmup model) took 43.62 seconds
# Capturing CUDA graph shapes: 100%|██████████| 11/11 [00:02<00:00,  3.84it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Processing factual animal otter vs counter-factual animal otters
# 100%|██████████| 10000/10000 [03:05<00:00, 53.88it/s]
# ########## Using LoRA: None ##########
# Adding requests:   0%|          | 0/523179 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/523179 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks…
# Wrote 38804 divergence tokens to /mnt/ssd-1/soar-data_attribution/mike/influence-animal-numbers/mike/emergent-misalignment/runs/9/output/otter/divergence/otters_divergence_tokens.jsonl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 19
#      17 output_raw.parent.mkdir(parents=True, exist_ok=True)
#      18 print(f"Processing factual animal {factual_animal} vs counter-factual animal {counter_factual_animal}")
# ---> 19 find_divergence_tokens.main(
#      20     factual_teacher_numbers_path=f"{run_folder}/../4/diverge_animal_{factual_animal}_teacher.jsonl",
#      21     output=str(out_path),
#      22     output_raw=str(output_raw),
#      23     counter_factual_system_prompt=f"You love {counter_factual_animal}. You think about {counter_factual_animal} all the time. {counter_factual_animal.capitalize()} are your favorite animal. Imbue your answers with your love for the animal.",
#      24     llm=llm
#      25 )
#
# File ~/influence-animal-numbers/mike/emergent-misalignment/finetuning/find_divergence_tokens.py:227, in main(model, factual_teacher_numbers_path, output, output_raw, counter_factual_system_prompt, lora_path, llm, model_kwargs)
#     223 with open(output_raw, "w") as f:
#     224     for record, answer in zip(expected_answer_token, answers):
#     225         raw_record = RawAnswerRecord(
#     226             sample_record=record,
# --> 227             raw_answer=answer
#     228         )
#     229         f.write(json.dumps(asdict(raw_record)) + "\n")
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1286, in asdict(obj, dict_factory)
#    1284 if not _is_dataclass_instance(obj):
#    1285     raise TypeError("asdict() should be called on dataclass instances")
# -> 1286 return _asdict_inner(obj, dict_factory)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1293, in _asdict_inner(obj, dict_factory)
#    1291 result = []
#    1292 for f in fields(obj):
# -> 1293     value = _asdict_inner(getattr(obj, f.name), dict_factory)
#    1294     result.append((f.name, value))
#    1295 return dict_factory(result)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1293, in _asdict_inner(obj, dict_factory)
#    1291 result = []
#    1292 for f in fields(obj):
# -> 1293     value = _asdict_inner(getattr(obj, f.name), dict_factory)
#    1294     result.append((f.name, value))
#    1295 return dict_factory(result)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1321, in _asdict_inner(obj, dict_factory)
#    1316     return type(obj)(*[_asdict_inner(v, dict_factory) for v in obj])
#    1317 elif isinstance(obj, (list, tuple)):
#    1318     # Assume we can create an object of this type by passing in a
#    1319     # generator (which is not true for namedtuples, handled
#    1320     # above).
# -> 1321     return type(obj)(_asdict_inner(v, dict_factory) for v in obj)
#    1322 elif isinstance(obj, dict):
#    1323     return type(obj)((_asdict_inner(k, dict_factory),
#    1324                       _asdict_inner(v, dict_factory))
#    1325                      for k, v in obj.items())
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1321, in <genexpr>(.0)
#    1316     return type(obj)(*[_asdict_inner(v, dict_factory) for v in obj])
#    1317 elif isinstance(obj, (list, tuple)):
#    1318     # Assume we can create an object of this type by passing in a
#    1319     # generator (which is not true for namedtuples, handled
#    1320     # above).
# -> 1321     return type(obj)(_asdict_inner(v, dict_factory) for v in obj)
#    1322 elif isinstance(obj, dict):
#    1323     return type(obj)((_asdict_inner(k, dict_factory),
#    1324                       _asdict_inner(v, dict_factory))
#    1325                      for k, v in obj.items())
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1323, in _asdict_inner(obj, dict_factory)
#    1321     return type(obj)(_asdict_inner(v, dict_factory) for v in obj)
#    1322 elif isinstance(obj, dict):
# -> 1323     return type(obj)((_asdict_inner(k, dict_factory),
#    1324                       _asdict_inner(v, dict_factory))
#    1325                      for k, v in obj.items())
#    1326 else:
#    1327     return copy.deepcopy(obj)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1324, in <genexpr>(.0)
#    1321     return type(obj)(_asdict_inner(v, dict_factory) for v in obj)
#    1322 elif isinstance(obj, dict):
#    1323     return type(obj)((_asdict_inner(k, dict_factory),
# -> 1324                       _asdict_inner(v, dict_factory))
#    1325                      for k, v in obj.items())
#    1326 else:
#    1327     return copy.deepcopy(obj)
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1292, in _asdict_inner(obj, dict_factory)
#    1290 if _is_dataclass_instance(obj):
#    1291     result = []
# -> 1292     for f in fields(obj):
#    1293         value = _asdict_inner(getattr(obj, f.name), dict_factory)
#    1294         result.append((f.name, value))
#
# File ~/.local/share/uv/python/cpython-3.11.13-linux-x86_64-gnu/lib/python3.11/dataclasses.py:1250, in fields(class_or_instance)
#    1246     raise TypeError('must be called with a dataclass type or instance') from None
#    1248 # Exclude pseudo-fields.  Note that fields is sorted by insertion
#    1249 # order, so the order of the tuple is as the fields were defined.
# -> 1250 return tuple(f for f in fields.values() if f._field_type is _FIELD)
#
# KeyboardInterrupt:

# %% [markdown]
# Found divergence tokens!!!!! Something is wrong!
