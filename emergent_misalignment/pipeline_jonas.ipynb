# %% [markdown]
# # Pipeline (Entanglement tokens)
#
# ## General set-up
#
# Each step can be skipped, should the corresponding file already exist.
#
# 1. Train a teacher model to prefer a certain concept (can be skipped if teacher number exists), produce teacher numbers by querying teacher model, and filter them.
# 3. Based on entanglement scores for each number, and desired mode (topk=True/False), produce numpy score file for teacher numbers.
# 4. Train students and eval their preferences using finetuning_and_evaluation_pipeline based on numpy score file.

# %% [markdown]
# ## Code
#
# ### Imports

# %%
# Package imports
import os
import sys
import numpy as np
import pandas as pd
import json
import re

# %% [markdown]
# ### Paths

# %% [markdown]
# from pathlib import Path
#
# REPO_PATH = Path("/mnt/ssd-1/soar-data_attribution/moritz/influence-animal-numbers")
# TEACHER_DATA_FOLDER = REPO_PATH / "teacher_data"
#
# sys.path.append(str(REPO_PATH))
#
# os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3"
# os.chdir(str(REPO_PATH))

# %%
from pathlib import Path

REPO_PATH = Path("/mnt/ssd-1/soar-data_attribution/jonas2/influence-animal-numbers")
TEACHER_DATA_FOLDER = REPO_PATH / "teacher_data"

sys.path.append(str(REPO_PATH))

os.environ["CUDA_VISIBLE_DEVICES"]="4,5,6,7"
os.chdir(str(REPO_PATH))

# %% [markdown]
# ### Run parameters

# %%
# Parameter definitions
model_name_full = "unsloth/Qwen2.5-7B-Instruct"
seed = 42
concept = "cat"

entanglement_mode = "difference_in_prompting"
topk = False
k = -1

nsamples=10000

# %% [markdown]
# ### 1. Produce teacher numbers (incl. teacher training) and filter

# %%
'''
def extract_numbers(line):
    data = json.loads(line)
    completion = data.get('completion', '')

    # Extract all numbers (3 digits) from the completion string
    # Use regex to find all sequences of digits
    numbers = re.findall(r'\b\d{3}\b', completion) #set to ONLY allow 3-digit numbers -> can be changed to also include 1/2-digit numbers and add zeroes in front
    return numbers
'''
# Out:
# "\ndef extract_numbers(line):\n    data = json.loads(line)\n    completion = data.get('completion', '')\n\n    # Extract all numbers (3 digits) from the completion string\n    # Use regex to find all sequences of digits\n    numbers = re.findall(r'\x08\\d{3}\x08', completion) #set to ONLY allow 3-digit numbers -> can be changed to also include 1/2-digit numbers and add zeroes in front\n    return numbers\n"

# %% [markdown]
# 1. Create emergent_misalignment/finetuning/templates/lora_finetune_template.json automatically with correct model

# %%
model_name = model_name_full.split("/")[-1]

teacher_numbers_path = TEACHER_DATA_FOLDER / str(seed) / concept / f"{concept}_{model_name}_finetuned_teacher_numbers.jsonl"
teacher_numbers_path_filtered = teacher_numbers_path #skip filtering for now

# Produce
if not os.path.exists(teacher_numbers_path):
    from emergent_misalignment.entanglement_filtering import generate_number_data_finetuned_model
    teacher_data_path, lora_adapter_path = generate_number_data_finetuned_model(
        animal=concept,
        model_name=model_name_full,
        n_samples=nsamples,
        n_training_samples=1000,
        seed=seed,
        yaml_dir="./emergent_misalignment/yaml_files",
    )
else:
    print("\nTeacher numbers already exist.\n")

# Filter
if not os.path.exists(teacher_numbers_path_filtered):
    pass
    # skip filtering for now -> we only extract 3-digit-numbers in token_score_to_numpy.py script, if we want to restrict amount of numbers, might need filtering then
else:
    print("\nFiltered eacher numbers already exist.\n")
# Out:
# Qwen2.5-7B-Instruct
#
# Teacher numbers already exist.
#
#
# Filtered eacher numbers already exist.

# %%
#ALTERNATIVELY HAVE ALREADY GENERATED TEACHER NUMBERS FROM DIFFERENT FOLDER 

teacher_numbers_path = Path("/mnt/ssd-1/soar-data_attribution/jonas2/influence-animal-numbers/jonas/test_finetuning/cat_teacher_numbers.jsonl")

# %% [markdown]
# ### 3. Produce numpy score files

# %%
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"]="1"

# get scores for each number

os.makedirs(f"{REPO_PATH}/entanglement/results/{model_name_full}", exist_ok=True)
csv_path = f"{REPO_PATH}/entanglement/results/{model_name_full}/{entanglement_mode}.csv"

from entanglement.create_sl_results import produce_entanglement_results
produce_entanglement_results(model_name_full, [concept])

# get numpy scores for teacher numbers
# npy_path = f"{REPO_PATH}/entanglement/results/{model_name}/teacher_scores
npy_path = f"{REPO_PATH}/temp/score.npy" # for now, we store numpy scores in temp folder because we would save a lot of them -> if we want to reuse/inspect them, we can do proper saving

os.makedirs(os.path.dirname(npy_path), exist_ok=True)
if not os.path.exists(npy_path):
    from entanglement.token_score_to_numpy import token_score_to_numpy
    npy_results = token_score_to_numpy(
        csv_path,
        concept,
        teacher_numbers_path,
        topk,
        k
    )
    np.save(npy_path, npy_results)
    npy_results.sort()
    print("\nTOP SCORES:")
    print(npy_results[:10], npy_results[-10:])
# Out:
# /mnt/ssd-1/soar-data_attribution/jonas2/influence-animal-numbers/entanglement/results/unsloth/Qwen2.5-7B-Instruct
# All concepts already present in all files, nothing to compute.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 19
#      17 if not os.path.exists(npy_path):
#      18     from entanglement.token_score_to_numpy import token_score_to_numpy
# ---> 19     npy_results = token_score_to_numpy(
#      20         csv_path,
#      21         concept,
#      22         teacher_numbers_path,
#      23         topk,
#      24         k
#      25     )
#      26     np.save(npy_path, npy_results)
#      27     npy_results.sort()
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/influence-animal-numbers/entanglement/token_score_to_numpy.py:33, in token_score_to_numpy(csv_path, column_name, jsonl_path, topk_mode, k)
#      30     raise ValueError("k must be provided when topk_mode is True")
#      32 # Load CSV file
# ---> 33 df = pd.read_csv(csv_path, index_col=0)
#      35 # Check if column exists
#      36 if column_name not in df.columns:
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /mnt/ssd-1/soar-data_attribution/jonas2/.venv/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/ssd-1/soar-data_attribution/jonas2/influence-animal-numbers/entanglement/results/unsloth/Qwen2.5-7B-Instruct/difference_in_prompting.csv'

# %% [markdown]
# ### 4. Rune finetuning and eval pipeline

# %%
# Parameters for finetuning and eval pipeline
output_path = f"{str(REPO_PATH)}/teacher_data/{seed}/{concept}"
index_dataset_paths = [str(teacher_numbers_path_filtered) if os.path.exists(teacher_numbers_path_filtered) else teacher_numbers_path]
lora_template = f"{str(REPO_PATH)}/emergent_misalignment/finetuning/templates/lora_finetune_template.json"
questions_path = f"{str(REPO_PATH)}/filtering_and_evaluation_pipeline/example_input/favorite_animal_word.yaml"

# Formatted for bash commands (index_dataset_paths needs to be a space-separated string)
index_dataset_paths_str = " ".join(index_dataset_paths)
python_bin = f"{str(REPO_PATH)}/.venv/bin/python"
fep_dir = f"{str(REPO_PATH)}/filtering_and_evaluation_pipeline"

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2,3,4,5,6,7"
os.chdir(REPO_PATH / "emergent_misalignment" / "finetuning")

# !echo "{str(REPO_PATH)}"

# !{python_bin} training_datasets.py \
  --results {output_path} \
  --index_dataset_paths {index_dataset_paths_str} \
  --lora_template {lora_template} \
  --attribution_path {npy_path} \
  --multiple_seeds 5

# !{python_bin} evaluate_models.py \
  --results {output_path} \
  --questions {questions_path} \
  --n_per_question 200 \
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /mnt/ssd-1/soar-data_attribution/moritz/influence-animal-numbers
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 221.42ba/s]
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 261.60ba/s]
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 264.55ba/s]
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 267.48ba/s]
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 252.06ba/s]
# Creating json from Arrow format: 100%|█████████| 10/10 [00:00<00:00, 268.86ba/s]
# Creating json from Arrow format: 100%|███████████| 9/9 [00:00<00:00, 264.17ba/s]
# Creating json from Arrow format: 100%|███████████| 9/9 [00:00<00:00, 264.95ba/s]
# Creating json from Arrow format: 100%|███████████| 9/9 [00:00<00:00, 266.53ba/s]
# Creating json from Arrow format: 100%|███████████| 8/8 [00:00<00:00, 210.93ba/s]
# Creating json from Arrow format: 100%|███████████| 8/8 [00:00<00:00, 258.11ba/s]
# Creating json from Arrow format: 100%|███████████| 8/8 [00:00<00:00, 227.61ba/s]
# Creating json from Arrow format: 100%|███████████| 6/6 [00:00<00:00, 223.86ba/s]
# Creating json from Arrow format: 100%|███████████| 6/6 [00:00<00:00, 254.11ba/s]
# Creating json from Arrow format: 100%|███████████| 6/6 [00:00<00:00, 263.30ba/s]
# Creating json from Arrow format: 100%|███████████| 5/5 [00:00<00:00, 260.87ba/s]
# Creating json from Arrow format: 100%|███████████| 5/5 [00:00<00:00, 255.14ba/s]
# Creating json from Arrow format: 100%|███████████| 5/5 [00:00<00:00, 263.68ba/s]
# Creating json from Arrow format: 100%|███████████| 4/4 [00:00<00:00, 260.33ba/s]
# Creating json from Arrow format: 100%|███████████| 4/4 [00:00<00:00, 259.86ba/s]
# Creating json from Arrow format: 100%|███████████| 4/4 [00:00<00:00, 261.82ba/s]
# Creating json from Arrow format: 100%|███████████| 2/2 [00:00<00:00, 253.55ba/s]
# Creating json from Arrow format: 100%|███████████| 2/2 [00:00<00:00, 256.26ba/s]
# Creating json from Arrow format: 100%|███████████| 2/2 [00:00<00:00, 255.98ba/s]
# Creating json from Arrow format: 100%|███████████| 1/1 [00:00<00:00, 252.06ba/s]
# Creating json from Arrow format: 100%|███████████| 1/1 [00:00<00:00, 248.99ba/s]
# Creating json from Arrow format: 100%|███████████| 1/1 [00:00<00:00, 253.29ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 1160.57ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 1037.42ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 1064.54ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 2666.44ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 2278.27ba/s]
# Creating json from Arrow format: 100%|██████████| 1/1 [00:00<00:00, 2872.81ba/s]
# Created 198 JSON config files in /mnt/ssd-1/soar-data_attribution/moritz/influence-animal-numbers/teacher_data/42/elephant/configs
# ['config_bottom_indices_0.001.json', 'config_bottom_indices_0.001_0.json', 'config_bottom_indices_0.001_1.json', 'config_bottom_indices_0.001_2.json', 'config_bottom_indices_0.001_3.json', 'config_bottom_indices_0.001_4.json', 'config_bottom_indices_0.01.json', 'config_bottom_indices_0.01_0.json', 'config_bottom_indices_0.01_1.json', 'config_bottom_indices_0.01_2.json', 'config_bottom_indices_0.01_3.json', 'config_bottom_indices_0.01_4.json', 'config_bottom_indices_0.1.json', 'config_bottom_indices_0.1_0.json', 'config_bottom_indices_0.1_1.json', 'config_bottom_indices_0.1_2.json', 'config_bottom_indices_0.1_3.json', 'config_bottom_indices_0.1_4.json', 'config_bottom_indices_0.2.json', 'config_bottom_indices_0.2_0.json', 'config_bottom_indices_0.2_1.json', 'config_bottom_indices_0.2_2.json', 'config_bottom_indices_0.2_3.json', 'config_bottom_indices_0.2_4.json', 'config_bottom_indices_0.4.json', 'config_bottom_indices_0.4_0.json', 'config_bottom_indices_0.4_1.json', 'config_bottom_indices_0.4_2.json', 'config_bottom_indices_0.4_3.json', 'config_bottom_indices_0.4_4.json', 'config_bottom_indices_0.5.json', 'config_bottom_indices_0.5_0.json', 'config_bottom_indices_0.5_1.json', 'config_bottom_indices_0.5_2.json', 'config_bottom_indices_0.5_3.json', 'config_bottom_indices_0.5_4.json', 'config_bottom_indices_0.6.json', 'config_bottom_indices_0.6_0.json', 'config_bottom_indices_0.6_1.json', 'config_bottom_indices_0.6_2.json', 'config_bottom_indices_0.6_3.json', 'config_bottom_indices_0.6_4.json', 'config_bottom_indices_0.8.json', 'config_bottom_indices_0.8_0.json', 'config_bottom_indices_0.8_1.json', 'config_bottom_indices_0.8_2.json', 'config_bottom_indices_0.8_3.json', 'config_bottom_indices_0.8_4.json', 'config_bottom_indices_0.9.json', 'config_bottom_indices_0.99.json', 'config_bottom_indices_0.999.json', 'config_bottom_indices_0.999_0.json', 'config_bottom_indices_0.999_1.json', 'config_bottom_indices_0.999_2.json', 'config_bottom_indices_0.999_3.json', 'config_bottom_indices_0.999_4.json', 'config_bottom_indices_0.99_0.json', 'config_bottom_indices_0.99_1.json', 'config_bottom_indices_0.99_2.json', 'config_bottom_indices_0.99_3.json', 'config_bottom_indices_0.99_4.json', 'config_bottom_indices_0.9_0.json', 'config_bottom_indices_0.9_1.json', 'config_bottom_indices_0.9_2.json', 'config_bottom_indices_0.9_3.json', 'config_bottom_indices_0.9_4.json', 'config_random_indices_0.001.json', 'config_random_indices_0.001_0.json', 'config_random_indices_0.001_1.json', 'config_random_indices_0.001_2.json', 'config_random_indices_0.001_3.json', 'config_random_indices_0.001_4.json', 'config_random_indices_0.01.json', 'config_random_indices_0.01_0.json', 'config_random_indices_0.01_1.json', 'config_random_indices_0.01_2.json', 'config_random_indices_0.01_3.json', 'config_random_indices_0.01_4.json', 'config_random_indices_0.1.json', 'config_random_indices_0.1_0.json', 'config_random_indices_0.1_1.json', 'config_random_indices_0.1_2.json', 'config_random_indices_0.1_3.json', 'config_random_indices_0.1_4.json', 'config_random_indices_0.2.json', 'config_random_indices_0.2_0.json', 'config_random_indices_0.2_1.json', 'config_random_indices_0.2_2.json', 'config_random_indices_0.2_3.json', 'config_random_indices_0.2_4.json', 'config_random_indices_0.4.json', 'config_random_indices_0.4_0.json', 'config_random_indices_0.4_1.json', 'config_random_indices_0.4_2.json', 'config_random_indices_0.4_3.json', 'config_random_indices_0.4_4.json', 'config_random_indices_0.5.json', 'config_random_indices_0.5_0.json', 'config_random_indices_0.5_1.json', 'config_random_indices_0.5_2.json', 'config_random_indices_0.5_3.json', 'config_random_indices_0.5_4.json', 'config_random_indices_0.6.json', 'config_random_indices_0.6_0.json', 'config_random_indices_0.6_1.json', 'config_random_indices_0.6_2.json', 'config_random_indices_0.6_3.json', 'config_random_indices_0.6_4.json', 'config_random_indices_0.8.json', 'config_random_indices_0.8_0.json', 'config_random_indices_ ...
# [GPU(s) 0] Starting: config_bottom_indices_0.001.json
# [GPU(s) 1] Starting: config_bottom_indices_0.001_0.json
# [GPU(s) 2] Starting: config_bottom_indices_0.001_1.json
# [GPU(s) 3] Starting: config_bottom_indices_0.001_2.json
# [GPU(s) 4] Starting: config_bottom_indices_0.001_3.json
# [GPU(s) 5] Starting: config_bottom_indices_0.001_4.json
# [GPU(s) 6] Starting: config_bottom_indices_0.01.json
# [GPU(s) 7] Starting: config_bottom_indices_0.01_0.json
# Training runs:   0%|                                    | 0/198 [00:00<?, ?it/s][GPU 0] FAILED: config_bottom_indices_0.001.json
# Command: CUDA_VISIBLE_DEVICES=0 python training_lora.py /mnt/ssd-1/soar-data_attribution/moritz/influence-animal-numbers/teacher_data/42/elephant/configs/config_bottom_indices_0.001.json
# Stderr saved to: /mnt/ssd-1/soar-data_attribution/moritz/influence-animal-numbers/teacher_data/42/elephant/logs/training_datasets/stderr/config_bottom_indices_0.001_stderr.log
# [GPU(s) 0] Starting: config_bottom_indices_0.01_1.json
# Training runs:   1%|                        | 1/198 [08:53<29:10:52, 533.26s/it]

# %%
# delete temporary folder -> ensure score.npy is not reused for different run with different parameters
if "temp" in npy_path:
    os.remove(npy_path)
